# %% [markdown]
# ### Goalie Summary

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\goalies\goalie_summary.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\goalies\goalie_summary.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['assists', 'gameDate', 'gameId', 'gamesPlayed', 'gamesStarted', 'goalieFullName', 'goals', 'goalsAgainst', 'goalsAgainstAverage', 'homeRoad', 'lastName', 'losses', 'opponentTeamAbbrev', 'otLosses', 'penaltyMinutes', 'playerId', 'points', 'savePct', 'saves', 'shootsCatches', 'shotsAgainst', 'shutouts', 'teamAbbrev', 'timeOnIce', 'wins']

# %%
df.columns
# Out:
# Index(['assists', 'gameDate', 'gameId', 'gamesPlayed', 'gamesStarted',
#        'goalieFullName', 'goals', 'goalsAgainst', 'goalsAgainstAverage',
#        'homeRoad', 'lastName', 'losses', 'opponentTeamAbbrev', 'otLosses',
#        'penaltyMinutes', 'playerId', 'points', 'savePct', 'saves',
#        'shootsCatches', 'shotsAgainst', 'shutouts', 'teamAbbrev', 'timeOnIce',
#        'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "goalieFullName", "playerId", "homeRoad",
    "teamAbbrev", "opponentTeamAbbrev", "shootsCatches", "gamesPlayed",
    "gamesStarted", "wins", "losses", "otLosses", "shotsAgainst",
    "saves", "goalsAgainst", "savePct", "goalsAgainstAverage",
    "timeOnIce", "shutouts", "goals", "assists", "points",
    "penaltyMinutes", "lastName"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'goalieFullName', 'playerId', 'homeRoad',
#        'teamAbbrev', 'opponentTeamAbbrev', 'shootsCatches', 'gamesPlayed',
#        'gamesStarted', 'wins', 'losses', 'otLosses', 'shotsAgainst', 'saves',
#        'goalsAgainst', 'savePct', 'goalsAgainstAverage', 'timeOnIce',
#        'shutouts', 'goals', 'assists', 'points', 'penaltyMinutes', 'lastName'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Goalie Bios

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\goalies\goalie_bios.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\goalies\goalie_bios.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['birthCity', 'birthCountryCode', 'birthDate', 'birthStateProvinceCode', 'currentTeamAbbrev', 'draftOverall', 'draftRound', 'draftYear', 'firstSeasonForGameType', 'gamesPlayed', 'goalieFullName', 'height', 'isInHallOfFameYn', 'lastName', 'losses', 'nationalityCode', 'otLosses', 'playerId', 'shootsCatches', 'shutouts', 'ties', 'weight', 'wins']

# %%
df.columns
# Out:
# Index(['birthCity', 'birthCountryCode', 'birthDate', 'birthStateProvinceCode',
#        'currentTeamAbbrev', 'draftOverall', 'draftRound', 'draftYear',
#        'firstSeasonForGameType', 'gamesPlayed', 'goalieFullName', 'height',
#        'isInHallOfFameYn', 'lastName', 'losses', 'nationalityCode', 'otLosses',
#        'playerId', 'shootsCatches', 'shutouts', 'ties', 'weight', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "goalieFullName", "playerId", "currentTeamAbbrev", "shootsCatches",
    "birthDate", "birthCity", "birthStateProvinceCode",
    "birthCountryCode", "nationalityCode", "height", "weight",
    "draftYear", "draftRound", "draftOverall", "firstSeasonForGameType",
    "isInHallOfFameYn", "gamesPlayed", "wins", "losses", "ties",
    "otLosses", "shutouts", "lastName"
]

df = df[desired_order]
df.columns
# Out:
# Index(['goalieFullName', 'playerId', 'currentTeamAbbrev', 'shootsCatches',
#        'birthDate', 'birthCity', 'birthStateProvinceCode', 'birthCountryCode',
#        'nationalityCode', 'height', 'weight', 'draftYear', 'draftRound',
#        'draftOverall', 'firstSeasonForGameType', 'isInHallOfFameYn',
#        'gamesPlayed', 'wins', 'losses', 'ties', 'otLosses', 'shutouts',
#        'lastName'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Goalie Advanced

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\goalies\goalie_advanced.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\goalies\goalie_advanced.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['completeGamePct', 'completeGames', 'gameDate', 'gameId', 'gamesPlayed', 'gamesStarted', 'goalieFullName', 'goalsAgainst', 'goalsAgainstAverage', 'goalsFor', 'goalsForAverage', 'homeRoad', 'incompleteGames', 'lastName', 'opponentTeamAbbrev', 'playerId', 'qualityStart', 'qualityStartsPct', 'regulationLosses', 'regulationWins', 'savePct', 'shootsCatches', 'shotsAgainstPer60', 'teamAbbrev', 'timeOnIce']

# %%
df.columns
# Out:
# Index(['completeGamePct', 'completeGames', 'gameDate', 'gameId', 'gamesPlayed',
#        'gamesStarted', 'goalieFullName', 'goalsAgainst', 'goalsAgainstAverage',
#        'goalsFor', 'goalsForAverage', 'homeRoad', 'incompleteGames',
#        'lastName', 'opponentTeamAbbrev', 'playerId', 'qualityStart',
#        'qualityStartsPct', 'regulationLosses', 'regulationWins', 'savePct',
#        'shootsCatches', 'shotsAgainstPer60', 'teamAbbrev', 'timeOnIce'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "goalieFullName", "playerId", "homeRoad",
    "teamAbbrev", "opponentTeamAbbrev", "shootsCatches", "gamesPlayed",
    "gamesStarted", "completeGames", "incompleteGames",
    "completeGamePct", "qualityStart", "qualityStartsPct", "goalsFor",
    "goalsAgainst", "goalsForAverage", "goalsAgainstAverage",
    "regulationWins", "regulationLosses", "shotsAgainstPer60",
    "savePct", "timeOnIce", "lastName"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'goalieFullName', 'playerId', 'homeRoad',
#        'teamAbbrev', 'opponentTeamAbbrev', 'shootsCatches', 'gamesPlayed',
#        'gamesStarted', 'completeGames', 'incompleteGames', 'completeGamePct',
#        'qualityStart', 'qualityStartsPct', 'goalsFor', 'goalsAgainst',
#        'goalsForAverage', 'goalsAgainstAverage', 'regulationWins',
#        'regulationLosses', 'shotsAgainstPer60', 'savePct', 'timeOnIce',
#        'lastName'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Goalie Days Rest

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\goalies\goalie_daysrest.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\goalies\goalie_daysrest.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'gamesPlayedDaysRest0', 'gamesPlayedDaysRest1', 'gamesPlayedDaysRest2', 'gamesPlayedDaysRest3', 'gamesPlayedDaysRest4Plus', 'gamesStarted', 'goalieFullName', 'homeRoad', 'lastName', 'losses', 'opponentTeamAbbrev', 'otLosses', 'playerId', 'savePct', 'savePctDaysRest4Plus', 'shootsCatches', 'teamAbbrev', 'wins', 'savePctDaysRest0', 'savePctDaysRest1', 'savePctDaysRest2', 'savePctDaysRest3']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'gamesPlayedDaysRest0',
#        'gamesPlayedDaysRest1', 'gamesPlayedDaysRest2', 'gamesPlayedDaysRest3',
#        'gamesPlayedDaysRest4Plus', 'gamesStarted', 'goalieFullName',
#        'homeRoad', 'lastName', 'losses', 'opponentTeamAbbrev', 'otLosses',
#        'playerId', 'savePct', 'savePctDaysRest4Plus', 'shootsCatches',
#        'teamAbbrev', 'wins', 'savePctDaysRest0', 'savePctDaysRest1',
#        'savePctDaysRest2', 'savePctDaysRest3'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "goalieFullName", "playerId", "homeRoad",
    "teamAbbrev", "opponentTeamAbbrev", "shootsCatches", "gamesPlayed",
    "gamesStarted", "wins", "losses", "otLosses", "savePct",
    "gamesPlayedDaysRest0", "gamesPlayedDaysRest1",
    "gamesPlayedDaysRest2", "gamesPlayedDaysRest3",
    "gamesPlayedDaysRest4Plus", "savePctDaysRest0", "savePctDaysRest1",
    "savePctDaysRest2", "savePctDaysRest3", "savePctDaysRest4Plus",
    "lastName"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'goalieFullName', 'playerId', 'homeRoad',
#        'teamAbbrev', 'opponentTeamAbbrev', 'shootsCatches', 'gamesPlayed',
#        'gamesStarted', 'wins', 'losses', 'otLosses', 'savePct',
#        'gamesPlayedDaysRest0', 'gamesPlayedDaysRest1', 'gamesPlayedDaysRest2',
#        'gamesPlayedDaysRest3', 'gamesPlayedDaysRest4Plus', 'savePctDaysRest0',
#        'savePctDaysRest1', 'savePctDaysRest2', 'savePctDaysRest3',
#        'savePctDaysRest4Plus', 'lastName'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Goalie Penalty Shots

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\goalies\goalie_penaltyShots.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\goalies\goalie_penaltyShots.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'goalieFullName', 'goalsAgainst', 'homeRoad', 'lastName', 'opponentTeamAbbrev', 'penaltyShotSavePct', 'penaltyShotsAgainst', 'penaltyShotsGoalsAgainst', 'penaltyShotsSaves', 'playerId', 'savePct', 'saves', 'shootsCatches', 'shotsAgainst', 'teamAbbrev']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'goalieFullName', 'goalsAgainst',
#        'homeRoad', 'lastName', 'opponentTeamAbbrev', 'penaltyShotSavePct',
#        'penaltyShotsAgainst', 'penaltyShotsGoalsAgainst', 'penaltyShotsSaves',
#        'playerId', 'savePct', 'saves', 'shootsCatches', 'shotsAgainst',
#        'teamAbbrev'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "goalieFullName", "playerId", "homeRoad",
    "teamAbbrev", "opponentTeamAbbrev", "shootsCatches", "gamesPlayed",
    "shotsAgainst", "saves", "goalsAgainst", "savePct",
    "penaltyShotsAgainst", "penaltyShotsSaves",
    "penaltyShotsGoalsAgainst", "penaltyShotSavePct", "lastName"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'goalieFullName', 'playerId', 'homeRoad',
#        'teamAbbrev', 'opponentTeamAbbrev', 'shootsCatches', 'gamesPlayed',
#        'shotsAgainst', 'saves', 'goalsAgainst', 'savePct',
#        'penaltyShotsAgainst', 'penaltyShotsSaves', 'penaltyShotsGoalsAgainst',
#        'penaltyShotSavePct', 'lastName'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Goalie Saves by Strength

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\goalies\goalie_savesByStrength.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\goalies\goalie_savesByStrength.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['evGoalsAgainst', 'evSavePct', 'evSaves', 'evShotsAgainst', 'gameDate', 'gameId', 'gamesPlayed', 'gamesStarted', 'goalieFullName', 'goalsAgainst', 'homeRoad', 'lastName', 'losses', 'opponentTeamAbbrev', 'otLosses', 'playerId', 'ppGoalsAgainst', 'ppSavePct', 'ppSaves', 'ppShotsAgainst', 'savePct', 'saves', 'shGoalsAgainst', 'shSavePct', 'shSaves', 'shShotsAgainst', 'shootsCatches', 'shotsAgainst', 'teamAbbrev', 'wins']

# %%
df.columns
# Out:
# Index(['evGoalsAgainst', 'evSavePct', 'evSaves', 'evShotsAgainst', 'gameDate',
#        'gameId', 'gamesPlayed', 'gamesStarted', 'goalieFullName',
#        'goalsAgainst', 'homeRoad', 'lastName', 'losses', 'opponentTeamAbbrev',
#        'otLosses', 'playerId', 'ppGoalsAgainst', 'ppSavePct', 'ppSaves',
#        'ppShotsAgainst', 'savePct', 'saves', 'shGoalsAgainst', 'shSavePct',
#        'shSaves', 'shShotsAgainst', 'shootsCatches', 'shotsAgainst',
#        'teamAbbrev', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "goalieFullName", "playerId", "homeRoad",
    "teamAbbrev", "opponentTeamAbbrev", "shootsCatches", "gamesPlayed",
    "gamesStarted", "wins", "losses", "otLosses", "shotsAgainst",
    "saves", "goalsAgainst", "savePct", "evShotsAgainst", "evSaves",
    "evGoalsAgainst", "evSavePct", "ppShotsAgainst", "ppSaves",
    "ppGoalsAgainst", "ppSavePct", "shShotsAgainst", "shSaves",
    "shGoalsAgainst", "shSavePct", "lastName"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'goalieFullName', 'playerId', 'homeRoad',
#        'teamAbbrev', 'opponentTeamAbbrev', 'shootsCatches', 'gamesPlayed',
#        'gamesStarted', 'wins', 'losses', 'otLosses', 'shotsAgainst', 'saves',
#        'goalsAgainst', 'savePct', 'evShotsAgainst', 'evSaves',
#        'evGoalsAgainst', 'evSavePct', 'ppShotsAgainst', 'ppSaves',
#        'ppGoalsAgainst', 'ppSavePct', 'shShotsAgainst', 'shSaves',
#        'shGoalsAgainst', 'shSavePct', 'lastName'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Goalie Shootout

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\goalies\goalie_shootout.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\goalies\goalie_shootout.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['careerShootoutGamesPlayed', 'careerShootoutGoalsAllowed', 'careerShootoutLosses', 'careerShootoutSavePct', 'careerShootoutSaves', 'careerShootoutShotsAgainst', 'careerShootoutWins', 'gameDate', 'gameId', 'gamesPlayed', 'goalieFullName', 'homeRoad', 'lastName', 'opponentTeamAbbrev', 'playerId', 'shootoutGoalsAgainst', 'shootoutLosses', 'shootoutSavePct', 'shootoutSaves', 'shootoutShotsAgainst', 'shootoutWins', 'shootsCatches', 'teamAbbrev']

# %%
df.columns
# Out:
# Index(['careerShootoutGamesPlayed', 'careerShootoutGoalsAllowed',
#        'careerShootoutLosses', 'careerShootoutSavePct', 'careerShootoutSaves',
#        'careerShootoutShotsAgainst', 'careerShootoutWins', 'gameDate',
#        'gameId', 'gamesPlayed', 'goalieFullName', 'homeRoad', 'lastName',
#        'opponentTeamAbbrev', 'playerId', 'shootoutGoalsAgainst',
#        'shootoutLosses', 'shootoutSavePct', 'shootoutSaves',
#        'shootoutShotsAgainst', 'shootoutWins', 'shootsCatches', 'teamAbbrev'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "goalieFullName", "playerId", "homeRoad",
    "teamAbbrev", "opponentTeamAbbrev", "shootsCatches", "gamesPlayed",
    "shootoutWins", "shootoutLosses", "shootoutShotsAgainst",
    "shootoutGoalsAgainst", "shootoutSaves", "shootoutSavePct",
    "careerShootoutGamesPlayed", "careerShootoutWins",
    "careerShootoutLosses", "careerShootoutShotsAgainst",
    "careerShootoutGoalsAllowed", "careerShootoutSaves",
    "careerShootoutSavePct", "lastName"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'goalieFullName', 'playerId', 'homeRoad',
#        'teamAbbrev', 'opponentTeamAbbrev', 'shootsCatches', 'gamesPlayed',
#        'shootoutWins', 'shootoutLosses', 'shootoutShotsAgainst',
#        'shootoutGoalsAgainst', 'shootoutSaves', 'shootoutSavePct',
#        'careerShootoutGamesPlayed', 'careerShootoutWins',
#        'careerShootoutLosses', 'careerShootoutShotsAgainst',
#        'careerShootoutGoalsAllowed', 'careerShootoutSaves',
#        'careerShootoutSavePct', 'lastName'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Goalie Started vs Relieved

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\goalies\goalie_startedVsRelieved.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\goalies\goalie_startedVsRelieved.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'gamesRelieved', 'gamesRelievedGoalsAgainst', 'gamesRelievedLosses', 'gamesRelievedOtLosses', 'gamesRelievedSaves', 'gamesRelievedShotsAgainst', 'gamesRelievedWins', 'gamesStarted', 'gamesStartedGoalsAgainst', 'gamesStartedLosses', 'gamesStartedOtLosses', 'gamesStartedSavePct', 'gamesStartedSaves', 'gamesStartedShotsAgainst', 'gamesStartedWins', 'goalieFullName', 'homeRoad', 'lastName', 'losses', 'opponentTeamAbbrev', 'otLosses', 'playerId', 'savePct', 'shootsCatches', 'teamAbbrev', 'wins', 'gamesRelievedSavePct']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'gamesRelieved',
#        'gamesRelievedGoalsAgainst', 'gamesRelievedLosses',
#        'gamesRelievedOtLosses', 'gamesRelievedSaves',
#        'gamesRelievedShotsAgainst', 'gamesRelievedWins', 'gamesStarted',
#        'gamesStartedGoalsAgainst', 'gamesStartedLosses',
#        'gamesStartedOtLosses', 'gamesStartedSavePct', 'gamesStartedSaves',
#        'gamesStartedShotsAgainst', 'gamesStartedWins', 'goalieFullName',
#        'homeRoad', 'lastName', 'losses', 'opponentTeamAbbrev', 'otLosses',
#        'playerId', 'savePct', 'shootsCatches', 'teamAbbrev', 'wins',
#        'gamesRelievedSavePct'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "goalieFullName", "playerId", "homeRoad",
    "teamAbbrev", "opponentTeamAbbrev", "shootsCatches", "gamesPlayed",
    "wins", "losses", "otLosses", "savePct", "gamesStarted",
    "gamesStartedWins", "gamesStartedLosses", "gamesStartedOtLosses",
    "gamesStartedShotsAgainst", "gamesStartedSaves",
    "gamesStartedGoalsAgainst", "gamesStartedSavePct",
    "gamesRelieved", "gamesRelievedWins", "gamesRelievedLosses",
    "gamesRelievedOtLosses", "gamesRelievedShotsAgainst",
    "gamesRelievedSaves", "gamesRelievedGoalsAgainst",
    "gamesRelievedSavePct", "lastName"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'goalieFullName', 'playerId', 'homeRoad',
#        'teamAbbrev', 'opponentTeamAbbrev', 'shootsCatches', 'gamesPlayed',
#        'wins', 'losses', 'otLosses', 'savePct', 'gamesStarted',
#        'gamesStartedWins', 'gamesStartedLosses', 'gamesStartedOtLosses',
#        'gamesStartedShotsAgainst', 'gamesStartedSaves',
#        'gamesStartedGoalsAgainst', 'gamesStartedSavePct', 'gamesRelieved',
#        'gamesRelievedWins', 'gamesRelievedLosses', 'gamesRelievedOtLosses',
#        'gamesRelievedShotsAgainst', 'gamesRelievedSaves',
#        'gamesRelievedGoalsAgainst', 'gamesRelievedSavePct', 'lastName'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### CONVERTING skater_summary.csv to JSON

# %%
import pandas as pd
from pathlib import Path

# === FILE PATHS ===
INPUT_PATH = Path(r"C:\Users\cadla\Desktop\Documents\2026-TopShelfAnalytics\topshelfanalytics-skater-table\skater_summary.csv")
OUTPUT_PATH = Path(r"C:\Users\cadla\Desktop\Documents\2026-TopShelfAnalytics\topshelfanalytics-skater-table\skater_summary.json")

# === LOAD CSV ===
df = pd.read_csv(INPUT_PATH)

# === OPTIONAL CLEANING ===

# Convert datetime columns to clean YYYY-MM-DD (adjust column names if needed)
for col in df.columns:
    if "date" in col.lower():
        try:
            df[col] = pd.to_datetime(df[col], errors="coerce").dt.strftime("%Y-%m-%d")
        except Exception:
            pass

# Replace NaN with None (better for JSON)
df = df.where(pd.notnull(df), None)

# === EXPORT JSON ===
df.to_json(
    OUTPUT_PATH,
    orient="records",   # list of row objects (best for frontend)
    indent=2            # pretty format (optional)
)

print(f"✅ JSON file created: {OUTPUT_PATH.resolve()}")
# Out:
# ✅ JSON file created: C:\Users\cadla\Desktop\Documents\2026-TopShelfAnalytics\topshelfanalytics-skater-table\skater_summary.json
